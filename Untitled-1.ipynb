# %%
from train import train, train_mpe
from common.config import Config

import os
import wandb
from dotenv import load_dotenv

# %%
load_dotenv()
wandb_key = os.getenv("WANDB_API_KEY")
wandb.login(key=wandb_key)

config = Config()
with wandb.init(project="wi-influence", config=config.__dict__):
    train_mpe(config=config)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\cbouchaa23\_netrc
# wandb: Currently logged in as: charbel-bouchaaya (charbel-bouchaaya-university-of-oulu) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# creating run (1.4s)
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\cbouchaa23\Desktop\gfn-marl\wandb\run-20260423_182100-hkvzx1xx</code>
# Syncing run <strong><a href='https://wandb.ai/charbel-bouchaaya-university-of-oulu/wi-influence/runs/hkvzx1xx' target="_blank">feasible-glitter-466</a></strong> to <a href='https://wandb.ai/charbel-bouchaaya-university-of-oulu/wi-influence' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/charbel-bouchaaya-university-of-oulu/wi-influence' target="_blank">https://wandb.ai/charbel-bouchaaya-university-of-oulu/wi-influence</a>
#  View run at <a href='https://wandb.ai/charbel-bouchaaya-university-of-oulu/wi-influence/runs/hkvzx1xx' target="_blank">https://wandb.ai/charbel-bouchaaya-university-of-oulu/wi-influence/runs/hkvzx1xx</a>
# Traceback (most recent call last):
#   File "C:\Users\cbouchaa23\AppData\Local\Temp\ipykernel_9008\3308821906.py", line 7, in <module>
#     train_mpe(config=config)
#   File "c:\Users\cbouchaa23\Desktop\gfn-marl\train.py", line 149, in train_mpe
#     actions, logits, value = agent.select_action(obs)
#   File "c:\Users\cbouchaa23\Desktop\gfn-marl\alg\mappo.py", line 210, in select_action
#     logits, value = self.policy(obs)
#   File "c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "c:\Users\cbouchaa23\Desktop\gfn-marl\common\nets.py", line 244, in forward
#     actor_logits = self.actor(observations).log_softmax(dim=-1)
#   File "c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\container.py", line 244, in forward
#     input = module(input)
#   File "c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\linear.py", line 125, in forward
#     return F.linear(input, self.weight, self.bias)
# KeyboardInterrupt
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>reward</td><td>▄▄▃▅▄▂▃▃▄▅▆▅▅▄▅▅▄▄▄▆▆▄▆▆▅█▅▆▅▆▆▄▅▁▄▅▅▅▅▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>reward</td><td>-10.41066</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">feasible-glitter-466</strong> at: <a href='https://wandb.ai/charbel-bouchaaya-university-of-oulu/wi-influence/runs/hkvzx1xx' target="_blank">https://wandb.ai/charbel-bouchaaya-university-of-oulu/wi-influence/runs/hkvzx1xx</a><br> View project at: <a href='https://wandb.ai/charbel-bouchaaya-university-of-oulu/wi-influence' target="_blank">https://wandb.ai/charbel-bouchaaya-university-of-oulu/wi-influence</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260423_182100-hkvzx1xx\logs</code>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 7
#       5 config = Config()
#       6 with wandb.init(project="wi-influence", config=config.__dict__):
# ----> 7     train_mpe(config=config)
#
# File c:\Users\cbouchaa23\Desktop\gfn-marl\train.py:149, in train_mpe(config, device, logging)
#     146 curr_reward = 0.0
#     148 while not doness.all():
# --> 149     actions, logits, value = agent.select_action(obs)
#     150     next_obs = env.step(actions)
#     151     rewards = torch.tensor([o[1][0] for o in next_obs])
#
# File c:\Users\cbouchaa23\Desktop\gfn-marl\alg\mappo.py:210, in MPE_MAPPO.select_action(self, obs)
#     208 with torch.no_grad():
#     209     obs = torch.from_numpy(np.stack(obs)).float().to(self.device)
# --> 210     logits, value = self.policy(obs)
#     211     action = torch.nn.functional.one_hot(
#     212         logits.softmax(-1)
#     213         .flatten(0, 1)
#    (...)
#     216         5,
#     217     )
#     219 return action, logits, value.squeeze()
#
# File c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\cbouchaa23\Desktop\gfn-marl\common\nets.py:244, in MPE_ACNetwork.forward(self, observations)
#     242 def forward(self, observations):
# --> 244     actor_logits = self.actor(observations).log_softmax(dim=-1)
#     245     value = self.critic(observations.flatten(1))
#     247     return actor_logits, value
#
# File c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\container.py:244, in Sequential.forward(self, input)
#     242 def forward(self, input):
#     243     for module in self:
# --> 244         input = module(input)
#     245     return input
#
# File c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
