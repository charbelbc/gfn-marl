# %%
from train import train
from common.config import Config

# %%
config = Config(env_name="MultiGrid-TwoTasksEnv-v0", batch_size=2, ppo_epochs=1)
train(config=config, logging=False)
# Out:
# c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\gymnasium\utils\passive_env_checker.py:29: UserWarning: WARN: It seems a Box observation space is an image but the `dtype` is not `np.uint8`, actual type: int32. If the Box observation space is not an image, we recommend flattening the observation to have only a 1D vector.
#   logger.warn(
# c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\gymnasium\utils\passive_env_checker.py:156: UserWarning: WARN: The obs returned by the `reset()` method should be an int or np.int64, actual type: <class 'numpy.int32'>
#   logger.warn(f"{pre} should be an int or np.int64, actual type: {type(obs)}")
# c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\gymnasium\utils\passive_env_checker.py:188: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\gymnasium\utils\passive_env_checker.py:257: UserWarning: WARN: Expects `terminated` signal to be a boolean, actual type: <class 'dict'>
#   logger.warn(
# c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\gymnasium\utils\passive_env_checker.py:261: UserWarning: WARN: Expects `truncated` signal to be a boolean, actual type: <class 'dict'>
#   logger.warn(
# c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\gymnasium\utils\passive_env_checker.py:156: UserWarning: WARN: The obs returned by the `step()` method should be an int or np.int64, actual type: <class 'numpy.int32'>
#   logger.warn(f"{pre} should be an int or np.int64, actual type: {type(obs)}")
# c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\gymnasium\utils\passive_env_checker.py:188: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\gymnasium\utils\passive_env_checker.py:275: UserWarning: WARN: The reward returned by `step()` must be a float, int, np.integer or np.floating, actual type: <class 'dict'>
#   logger.warn(
# 2
# 4
# 6
# 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 config = Config(env_name="MultiGrid-TwoTasksEnv-v0", batch_size=2, ppo_epochs=1)
# ----> 2 train(config=config, logging=False)
#
# File c:\Users\cbouchaa23\Desktop\gfn-marl\train.py:95, in train(config, device, logging)
#      92     step += 1
#      93     obs = next_obs
# ---> 95 agent.update(buffer)
#      96 buffer.reset_buffer()
#      97 episode += batch_size
#
# File c:\Users\cbouchaa23\Desktop\gfn-marl\alg\mappo.py:130, in MAPPO.update(self, buffer)
#     126 logits_now, values_now = [], []
#     128 for t in range(old_states.shape[1]):
# --> 130     logits, values, memory = self.policy(
#     131         old_states[
#     132             :,
#     133             t,
#     134         ],
#     135         memory,
#     136         instr,
#     137     )
#     139     logits_now.append(logits)
#     140     values_now.append(values)
#
# File c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\cbouchaa23\Desktop\gfn-marl\common\nets.py:162, in ACNetwork.forward(self, observations, memory, instr_tensor)
#     159 out, _ = self.instr_rnn(self.instr_emb(instr_tensor))
#     160 instr_embedding = out[range(len(lengths)), lengths - 1, :]
# --> 162 features = self.convnet(
#     163     self.image_emb(
#     164         observations.transpose(0, 1).reshape(batch * agents, *channels)
#     165     )
#     166 )
#     168 for controller in self.controllers:
#     169     x = controller(features, instr_embedding.repeat(agents, 1)) + features
#
# File c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\container.py:244, in Sequential.forward(self, input)
#     242 def forward(self, input):
#     243     for module in self:
# --> 244         input = module(input)
#     245     return input
#
# File c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\site-packages\torch\nn\modules\conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     531 if self.padding_mode != "zeros":
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# KeyboardInterrupt:
