# %%
from mpe.MPE_env import MPEEnv
from common.config import Config
import mediapy as media

env = MPEEnv(Config(num_agents=3, num_landmarks=3))
env.reset()
media.show_image(env.render(size=200))
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="200" height="200" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %%
from train import train_mpe
from common.config import Config
train_mpe(Config(), logging=False)
# Out:
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from train import train_mpe
#       2 from common.config import Config
# ----> 3 train_mpe(Config(), logging=False)
#
# File c:\Users\cbouchaa23\Desktop\gfn-marl\train.py:150, in train_mpe(config, device, logging)
#     148 while not doness.all():
#     149     actions, logits, value = agent.select_action(obs)
# --> 150     next_obs = env.step(actions.cpu())
#     151     rewards = torch.tensor([o[1][0] for o in next_obs])
#     152     dones = torch.tensor([o[2][0] for o in next_obs])
#
# File c:\Users\cbouchaa23\Desktop\gfn-marl\common\utils.py:59, in ParallelEnv.step(self, actions)
#      57 def step(self, actions):
#      58     for local, action in zip(self.locals, actions[1:]):
# ---> 59         local.send(("step", action))
#      60     # obs, reward, terminated, truncated, info = self.envs[0].step(actions[0])
#      61     # if terminated[0] or truncated[0]:
#      62     #     obs, _ = self.envs[0].reset()
#      63     # results = [(obs, reward, terminated, truncated, info)] + [
#      64     #     local.recv() for local in self.locals
#      65     # ]
#      66     obs, reward, terminated, info = self.envs[0].step(actions[0])
#
# File c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\multiprocessing\connection.py:206, in _ConnectionBase.send(self, obj)
#     204 self._check_closed()
#     205 self._check_writable()
# --> 206 self._send_bytes(_ForkingPickler.dumps(obj))
#
# File c:\Users\cbouchaa23\Anaconda3\envs\gfn\lib\multiprocessing\connection.py:280, in PipeConnection._send_bytes(self, buf)
#     279 def _send_bytes(self, buf):
# --> 280     ov, err = _winapi.WriteFile(self._handle, buf, overlapped=True)
#     281     try:
#     282         if err == _winapi.ERROR_IO_PENDING:
#
# KeyboardInterrupt:
